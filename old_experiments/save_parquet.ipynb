# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/raw/data_no_weather.parquet')
df
# Out:
#                   EIC-код Група       Дата  Year  Month  Day  Hour  \
# 0        62Z0008583037334     Б 2024-12-01  2024     12    1     1
# 1        62Z0008583037334     Б 2024-12-01  2024     12    1     2
# 2        62Z0008583037334     Б 2024-12-01  2024     12    1     3
# 3        62Z0008583037334     Б 2024-12-01  2024     12    1     4
# 4        62Z0008583037334     Б 2024-12-01  2024     12    1     5
# ...                   ...   ...        ...   ...    ...  ...   ...
# 4612447  62Z9997819406173     Б 2024-01-31  2024      1   31    20
# 4612448  62Z9997819406173     Б 2024-01-31  2024      1   31    21
# 4612449  62Z9997819406173     Б 2024-01-31  2024      1   31    22
# 4612450  62Z9997819406173     Б 2024-01-31  2024      1   31    23
# 4612451  62Z9997819406173     Б 2024-01-31  2024      1   31    24
#
#          Sum of кВт  Average of Ціна розподілу ЕЕ грн. без ПДВ/кВт*год  \
# 0         20.716983                                            2.15221
# ...

# %%
df_weathered = pd.read_parquet('../data/raw/data_with_weather.parquet')

# %%
df_weathered = pd.concat([df[~df['temperature_2m'].isna()], df_weathered]).copy()
df_weathered.to_parquet('data/raw/data_with_weather.parquet')
df_weathered
# Out:
#                   EIC-код Група       Дата  Year  Month  Day  Hour  \
# 4464     62Z0211989286227     Б 2024-12-01  2024     12    1     1
# 4465     62Z0211989286227     Б 2024-12-01  2024     12    1     2
# 4466     62Z0211989286227     Б 2024-12-01  2024     12    1     3
# 4467     62Z0211989286227     Б 2024-12-01  2024     12    1     4
# 4468     62Z0211989286227     Б 2024-12-01  2024     12    1     5
# ...                   ...   ...        ...   ...    ...  ...   ...
# 5439828  62Z9342951787758     Б 2024-01-31  2024      1   31    20
# 5439829  62Z9342951787758     Б 2024-01-31  2024      1   31    21
# 5439830  62Z9342951787758     Б 2024-01-31  2024      1   31    22
# 5439831  62Z9342951787758     Б 2024-01-31  2024      1   31    23
# 5439832  62Z9342951787758     Б 2024-01-31  2024      1   31    24
#
#          Sum of кВт  Average of Ціна розподілу ЕЕ грн. без ПДВ/кВт*год  \
# 4464      16.497020                                            1.46219
# ...

# %%
df[df['temperature_2m'].isna()].to_parquet('data/raw/data_no_weather.parquet')
df[df['temperature_2m'].isna()]
# Out:
#                   EIC-код Група       Дата  Year  Month  Day  Hour  \
# 0        62Z0008583037334     Б 2024-12-01  2024     12    1     1
# 1        62Z0008583037334     Б 2024-12-01  2024     12    1     2
# 2        62Z0008583037334     Б 2024-12-01  2024     12    1     3
# 3        62Z0008583037334     Б 2024-12-01  2024     12    1     4
# 4        62Z0008583037334     Б 2024-12-01  2024     12    1     5
# ...                   ...   ...        ...   ...    ...  ...   ...
# 4612447  62Z9997819406173     Б 2024-01-31  2024      1   31    20
# 4612448  62Z9997819406173     Б 2024-01-31  2024      1   31    21
# 4612449  62Z9997819406173     Б 2024-01-31  2024      1   31    22
# 4612450  62Z9997819406173     Б 2024-01-31  2024      1   31    23
# 4612451  62Z9997819406173     Б 2024-01-31  2024      1   31    24
#
#          Sum of кВт  Average of Ціна розподілу ЕЕ грн. без ПДВ/кВт*год  \
# 0         20.716983                                            2.15221
# ...

# %%
pd.concat([df_weathered, df]).to_parquet('../data/raw/full_concated_copy.parquet')
pd.concat([df_weathered, df])
# Out:
#                   EIC-код Група       Дата  Year  Month  Day  Hour  \
# 4464     62Z0211989286227     Б 2024-12-01  2024     12    1     1
# 4465     62Z0211989286227     Б 2024-12-01  2024     12    1     2
# 4466     62Z0211989286227     Б 2024-12-01  2024     12    1     3
# 4467     62Z0211989286227     Б 2024-12-01  2024     12    1     4
# 4468     62Z0211989286227     Б 2024-12-01  2024     12    1     5
# ...                   ...   ...        ...   ...    ...  ...   ...
# 4612447  62Z9997819406173     Б 2024-01-31  2024      1   31    20
# 4612448  62Z9997819406173     Б 2024-01-31  2024      1   31    21
# 4612449  62Z9997819406173     Б 2024-01-31  2024      1   31    22
# 4612450  62Z9997819406173     Б 2024-01-31  2024      1   31    23
# 4612451  62Z9997819406173     Б 2024-01-31  2024      1   31    24
#
#          Sum of кВт  Average of Ціна розподілу ЕЕ грн. без ПДВ/кВт*год  \
# 4464      16.497020                                            1.46219
# ...

# %%
# df = pd.read_parquet('data/raw/full_concated_copy.parquet')
# df.to_parquet('data/raw/full_concated_copy.parquet')
# df
# Out:
#                   EIC-код Група       Дата  Year  Month  Day  Hour  \
# 0        62Z0008583037334     Б 2024-12-01  2024     12    1     1
# 1        62Z0008583037334     Б 2024-12-01  2024     12    1     2
# 2        62Z0008583037334     Б 2024-12-01  2024     12    1     3
# 3        62Z0008583037334     Б 2024-12-01  2024     12    1     4
# 4        62Z0008583037334     Б 2024-12-01  2024     12    1     5
# ...                   ...   ...        ...   ...    ...  ...   ...
# 5454708  62Z9997819406173     Б 2024-01-31  2024      1   31    20
# 5454709  62Z9997819406173     Б 2024-01-31  2024      1   31    21
# 5454710  62Z9997819406173     Б 2024-01-31  2024      1   31    22
# 5454711  62Z9997819406173     Б 2024-01-31  2024      1   31    23
# 5454712  62Z9997819406173     Б 2024-01-31  2024      1   31    24
#
#          Sum of кВт  Average of Ціна розподілу ЕЕ грн. без ПДВ/кВт*год  \
# 0         20.716983                                            2.15221
# ...

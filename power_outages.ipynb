# %%
import pandas as pd

# %%
df = pd.read_parquet("data/silver_money_calc/train.parquet")
df
# Out:
#               EIC-код_cat  Група_cat  Sum of кВт  Ціна розподілу ЕЕ   Ціна ЕЕ  \
# 0        62Z0211989286227          0   16.497020            1.46219  6.136750
# 1        62Z0211989286227          0   14.932647            1.46219  6.136750
# 2        62Z0211989286227          0   14.363785            1.46219  6.136750
# 3        62Z0211989286227          0   13.794922            1.46219  6.136750
# 4        62Z0211989286227          0   13.937137            1.46219  6.136750
# ...                   ...        ...         ...                ...       ...
# 4864319  62Z5692449931680          0   12.619683            1.63103  3.662765
# 4864320  62Z5692449931680          0   12.331140            1.63103  3.662765
# 4864321  62Z5692449931680          0   11.568950            1.63103  3.662765
# 4864322  62Z5692449931680          0   10.534550            1.63103  3.662765
# 4864323  62Z5692449931680          0    9.532815            1.63103  3.662765
#
# ...
